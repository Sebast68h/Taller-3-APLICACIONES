# %%
import pandas as pd

# %%
df = pd.read_csv("estudiantes - Copy.csv")

# %%
df.head()
# Out:
#   student_id          programa  semestre  edad  genero  horas_estudio_semana  \
# 0      E0001          Economía         5    21   Mujer                  16.8
# 1      E0002    Administración         6    23   Mujer                  23.5
# 2      E0003    Administración         1    17  Hombre                  12.6
# 3      E0004  Ciencia de Datos         8    21   Mujer                  15.7
# 4      E0005            Diseño         3    22   Mujer                  20.5
#
#    horas_sueno_noche  tiempo_desplazamiento_min medio_transporte  \
# 0                5.5                       61.0              Bus
# 1                7.2                       98.0     TransMilenio
# 2                6.7                       55.0     TransMilenio
# 3                6.1                       57.0             Moto
# 4                6.4                       50.0            Carro
#
#    nivel_estres  satisfaccion_academica  dias_ejercicio_semana  \
# ...

# %%
df.student_id
# Out:
# 0       E0001
# 1       E0002
# 2       E0003
# 3       E0004
# 4       E0005
#         ...
# 2507    E2113
# 2508    E0456
# 2509    E1001
# 2510    E0438
# 2511    E1192
# Name: student_id, Length: 2512, dtype: str

# %%
col = df[["student_id","programa","semestre","edad"]]
col
# Out:
#      student_id                programa  semestre  edad
# 0         E0001                Economía         5    21
# 1         E0002          Administración         6    23
# 2         E0003          Administración         1    17
# 3         E0004        Ciencia de Datos         8    21
# 4         E0005                  Diseño         3    22
# ...         ...                     ...       ...   ...
# 2507      E2113        Ciencia de Datos         1    18
# 2508      E0456          Administración         2    19
# 2509      E1001  Ingeniería de Sistemas         1    19
# 2510      E0438   Ingeniería Industrial         1    19
# 2511      E1192          Administración         2    20
#
# [2512 rows x 4 columns]

# %%
df.iloc[3]
# Out:
# student_id                                  E0004
# programa                         Ciencia de Datos
# semestre                                        8
# edad                                           21
# genero                                      Mujer
# horas_estudio_semana                         15.7
# horas_sueno_noche                             6.1
# tiempo_desplazamiento_min                    57.0
# medio_transporte                             Moto
# nivel_estres                                    4
# satisfaccion_academica                          3
# dias_ejercicio_semana                           1
# horas_sociales_semana                        14.3
# uso_ia_generativa                           Nunca
# confianza_programando                           4
# area_interes_datos           Analítica de negocio
# modalidad_preferida                    Presencial
# promedio_acumulado                            2.9
# fecha_encuesta                         2026-08-19
# ...

# %%
df.iloc[3,0]
# Out:
# 'E0004'

# %%
df.loc[3,"student_id"]
# Out:
# 'E0004'

# %%
df.isna().sum()
# Out:
# student_id                    0
# programa                      0
# semestre                      0
# edad                          0
# genero                        0
# horas_estudio_semana          0
# horas_sueno_noche            72
# tiempo_desplazamiento_min    56
# medio_transporte              0
# nivel_estres                  0
# satisfaccion_academica        0
# dias_ejercicio_semana         0
# horas_sociales_semana         0
# uso_ia_generativa             0
# confianza_programando         0
# area_interes_datos           41
# modalidad_preferida           0
# promedio_acumulado            0
# fecha_encuesta                0
# dtype: int64

# %%
df.dropna(subset=["area_interes_datos"])
# Out:
#      student_id                programa  semestre  edad  genero  \
# 0         E0001                Economía         5    21   Mujer
# 1         E0002          Administración         6    23   Mujer
# 2         E0003          Administración         1    17  Hombre
# 3         E0004        Ciencia de Datos         8    21   Mujer
# 4         E0005                  Diseño         3    22   Mujer
# ...         ...                     ...       ...   ...     ...
# 2507      E2113        Ciencia de Datos         1    18   Mujer
# 2508      E0456          Administración         2    19   Mujer
# 2509      E1001  Ingeniería de Sistemas         1    19   Mujer
# 2510      E0438   Ingeniería Industrial         1    19   Mujer
# 2511      E1192          Administración         2    20   Mujer
#
#       horas_estudio_semana  horas_sueno_noche  tiempo_desplazamiento_min  \
# 0                     16.8                5.5                       61.0
# ...

# %%
df.drop_duplicates(subset=["programa"],keep="last")
# Out:
#      student_id                programa  semestre  edad  genero  \
# 2387      E2388           Ciencia Datos         4    18   Mujer
# 2501      E1077              Psicología         4    20  Hombre
# 2503      E0135                  Diseño         2    20   Mujer
# 2506      E2010                Economía         5    19  Hombre
# 2507      E2113        Ciencia de Datos         1    18   Mujer
# 2509      E1001  Ingeniería de Sistemas         1    19   Mujer
# 2510      E0438   Ingeniería Industrial         1    19   Mujer
# 2511      E1192          Administración         2    20   Mujer
#
#       horas_estudio_semana  horas_sueno_noche  tiempo_desplazamiento_min  \
# 2387                  15.1                7.5                        0.0
# 2501                  19.0                6.4                       58.0
# 2503                  15.2                7.6                       38.0
# 2506                  17.2                6.4                       26.0
# ...

# %% [markdown]
# ## 2.Filtros

# %%
  df[df["nivel_estres"] >= 4]
# Out:
#      student_id                programa  semestre  edad  genero  \
# 0         E0001                Economía         5    21   Mujer
# 1         E0002          Administración         6    23   Mujer
# 2         E0003          Administración         1    17  Hombre
# 3         E0004        Ciencia de Datos         8    21   Mujer
# 4         E0005                  Diseño         3    22   Mujer
# ...         ...                     ...       ...   ...     ...
# 2505      E1375        Ciencia de Datos         2    18   Mujer
# 2506      E2010                Economía         5    19  Hombre
# 2507      E2113        Ciencia de Datos         1    18   Mujer
# 2508      E0456          Administración         2    19   Mujer
# 2509      E1001  Ingeniería de Sistemas         1    19   Mujer
#
#       horas_estudio_semana  horas_sueno_noche  tiempo_desplazamiento_min  \
# 0                     16.8                5.5                       61.0
# ...

# %%
df[df["programa"] == "Ciencia de Datos"]
# Out:
#      student_id          programa  semestre  edad      genero  \
# 3         E0004  Ciencia de Datos         8    21       Mujer
# 5         E0006  Ciencia de Datos         4    22      Hombre
# 11        E0012  Ciencia de Datos         5    20       Mujer
# 13        E0014  Ciencia de Datos         4    24       Mujer
# 23        E0024  Ciencia de Datos         4    22       Mujer
# ...         ...               ...       ...   ...         ...
# 2475      E2476  Ciencia de Datos         5    22  No binario
# 2476      E2477  Ciencia de Datos         4    22      Hombre
# 2500      E1000  Ciencia de Datos         3    22       Mujer
# 2505      E1375  Ciencia de Datos         2    18       Mujer
# 2507      E2113  Ciencia de Datos         1    18       Mujer
#
#       horas_estudio_semana  horas_sueno_noche  tiempo_desplazamiento_min  \
# 3                     15.7                6.1                       57.0
# ...

# %%
df[df["semestre"].isin([1,2,3])]
# Out:
#      student_id                programa  semestre  edad  genero  \
# 2         E0003          Administración         1    17  Hombre
# 4         E0005                  Diseño         3    22   Mujer
# 6         E0007  Ingeniería de Sistemas         1    20  Hombre
# 10        E0011   Ingeniería Industrial         1    21   Mujer
# 14        E0015                Economía         3    22  Hombre
# ...         ...                     ...       ...   ...     ...
# 2507      E2113        Ciencia de Datos         1    18   Mujer
# 2508      E0456          Administración         2    19   Mujer
# 2509      E1001  Ingeniería de Sistemas         1    19   Mujer
# 2510      E0438   Ingeniería Industrial         1    19   Mujer
# 2511      E1192          Administración         2    20   Mujer
#
#       horas_estudio_semana  horas_sueno_noche  tiempo_desplazamiento_min  \
# 2                     12.6                6.7                       55.0
# ...

# %%
df.query("horas_sueno_noche >= 4")
# Out:
#      student_id                programa  semestre  edad  genero  \
# 0         E0001                Economía         5    21   Mujer
# 1         E0002          Administración         6    23   Mujer
# 2         E0003          Administración         1    17  Hombre
# 3         E0004        Ciencia de Datos         8    21   Mujer
# 4         E0005                  Diseño         3    22   Mujer
# ...         ...                     ...       ...   ...     ...
# 2507      E2113        Ciencia de Datos         1    18   Mujer
# 2508      E0456          Administración         2    19   Mujer
# 2509      E1001  Ingeniería de Sistemas         1    19   Mujer
# 2510      E0438   Ingeniería Industrial         1    19   Mujer
# 2511      E1192          Administración         2    20   Mujer
#
#       horas_estudio_semana  horas_sueno_noche  tiempo_desplazamiento_min  \
# 0                     16.8                5.5                       61.0
# ...

# %%
df[(df["nivel_estres"] >= 4) & (df["horas_sueno_noche"] < 6)]
# Out:
#      student_id                programa  semestre  edad  genero  \
# 0         E0001                Economía         5    21   Mujer
# 10        E0011   Ingeniería Industrial         1    21   Mujer
# 15        E0016              Psicología         1    20  Hombre
# 16        E0017  Ingeniería de Sistemas         4    25   Mujer
# 25        E0026                Economía         1    19  Hombre
# ...         ...                     ...       ...   ...     ...
# 2489      E2490          Administración         1    20  Hombre
# 2499      E2500   Ingeniería Industrial         6    22   Mujer
# 2500      E1000        Ciencia de Datos         3    22   Mujer
# 2508      E0456          Administración         2    19   Mujer
# 2509      E1001  Ingeniería de Sistemas         1    19   Mujer
#
#       horas_estudio_semana  horas_sueno_noche  tiempo_desplazamiento_min  \
# 0                     16.8                5.5                       61.0
# ...

# %%
df.query(" nivel_estres >= 4 or horas_sueno_noche < 6")
# Out:
#      student_id                programa  semestre  edad  genero  \
# 0         E0001                Economía         5    21   Mujer
# 1         E0002          Administración         6    23   Mujer
# 2         E0003          Administración         1    17  Hombre
# 3         E0004        Ciencia de Datos         8    21   Mujer
# 4         E0005                  Diseño         3    22   Mujer
# ...         ...                     ...       ...   ...     ...
# 2505      E1375        Ciencia de Datos         2    18   Mujer
# 2506      E2010                Economía         5    19  Hombre
# 2507      E2113        Ciencia de Datos         1    18   Mujer
# 2508      E0456          Administración         2    19   Mujer
# 2509      E1001  Ingeniería de Sistemas         1    19   Mujer
#
#       horas_estudio_semana  horas_sueno_noche  tiempo_desplazamiento_min  \
# 0                     16.8                5.5                       61.0
# ...

# %% [markdown]
# ## Transformaciones

# %%
df["fecha_encuesta"] = pd.to_datetime(df["fecha_encuesta"],errors="coerce")
df.dtypes
# Out:
# student_id                              str
# programa                                str
# semestre                              int64
# edad                                  int64
# genero                                  str
# horas_estudio_semana                float64
# horas_sueno_noche                   float64
# tiempo_desplazamiento_min           float64
# medio_transporte                        str
# nivel_estres                          int64
# satisfaccion_academica                int64
# dias_ejercicio_semana                 int64
# horas_sociales_semana               float64
# uso_ia_generativa                       str
# confianza_programando                 int64
# area_interes_datos                      str
# modalidad_preferida                     str
# promedio_acumulado                  float64
# fecha_encuesta               datetime64[us]
# dtype: object

# %%
df["programa"].value_counts()
# Out:
# programa
# Ciencia de Datos          475
# Ingeniería Industrial     453
# Ingeniería de Sistemas    427
# Economía                  383
# Administración            362
# Diseño                    209
# Psicología                200
# Ciencia Datos               3
# Name: count, dtype: int64

# %%
df["programa"] = df["programa"].str.replace("Ciencia Datos", "Ciencia de Datos")

# %%
df["programa"].value_counts()
# Out:
# programa
# Ciencia de Datos          478
# Ingeniería Industrial     453
# Ingeniería de Sistemas    427
# Economía                  383
# Administración            362
# Diseño                    209
# Psicología                200
# Name: count, dtype: int64

# %%
df["balance_estudio_sueño"] = df["horas_estudio_semana"] / (df["horas_sueño_noche"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...
